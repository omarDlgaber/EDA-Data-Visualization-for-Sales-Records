# %% [markdown]
# <a href="https://www.kaggle.com/code/omaradel99/eda-data-visualization-for-10000-sales-records?scriptVersionId=253186181" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **Sales and Customer Data** 🛒

# %% [markdown]
# > This dataset contains 10,000 sales transactions across different countries, product categories, and sales channels. It includes details about sales revenue, cost, and profit, helping us understand business performance and customer trends.

# %% [markdown]
# ## **🔍 Understanding the Dataset**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import folium
# import dash                         # Dash framework
# from dash import dcc, html
import warnings
warnings.filterwarnings('ignore')

# %%
def safe_comma_format(x):
    try:
        # If the number is integer (such as the year), return it as it is without decimal formatting.
        if float(x).is_integer() and int(float(x)) < 3000:  # Assume the year is less than 3000
            return str(int(x))
        return format(float(x), ",.2f")
    except (ValueError, TypeError):
        return x  # If it's not a number, return it as it is

# %% [markdown]
# # Importing and inspecting data

# %% [markdown]
# * read csv dataset

# %%
sales = pd.read_csv('/kaggle/input/10000-sales-records/10000 Sales Records.csv')

# %%
sales.head()
# Out:
#                          Region                           Country  \
# 0            Sub-Saharan Africa                              Chad
# 1                        Europe                            Latvia
# 2  Middle East and North Africa                          Pakistan
# 3            Sub-Saharan Africa  Democratic Republic of the Congo
# 4                        Europe                    Czech Republic
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0  Office Supplies        Online              L   1/27/2011  292494523
# 1        Beverages        Online              C  12/28/2015  361825549
# 2       Vegetables       Offline              C   1/13/2011  141515767
# 3        Household        Online              C   9/11/2012  500364005
# 4        Beverages        Online              C  10/27/2015  127481591
#
#    Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0  2/12/2011        4484      651.21     524.96     2920025.64  2353920.64
# 1  1/23/2016        1075       47.45      31.79       51008.75    34174.25
# 2   2/1/2011        6515      154.06      90.93     1003700.90   592408.95
# 3  10/6/2012        7683      668.27     502.54     5134318.41  3861014.82
# 4  12/5/2015        3491       47.45      31.79      165647.95   110978.89
#
#    Total Profit
# 0     566105.00
# 1      16834.50
# 2     411291.95
# 3    1273303.59
# 4      54669.06

# %%
sales.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          10000 non-null  object
#  1   Country         10000 non-null  object
#  2   Item Type       10000 non-null  object
#  3   Sales Channel   10000 non-null  object
#  4   Order Priority  10000 non-null  object
#  5   Order Date      10000 non-null  object
#  6   Order ID        10000 non-null  int64
#  7   Ship Date       10000 non-null  object
#  8   Units Sold      10000 non-null  int64
#  9   Unit Price      10000 non-null  float64
#  10  Unit Cost       10000 non-null  float64
#  11  Total Revenue   10000 non-null  float64
#  12  Total Cost      10000 non-null  float64
#  13  Total Profit    10000 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 1.1+ MB

# %%
sales.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
sales.isnull().sum() * 100 / len(sales)
# Out:
# Region            0.0
# Country           0.0
# Item Type         0.0
# Sales Channel     0.0
# Order Priority    0.0
# Order Date        0.0
# Order ID          0.0
# Ship Date         0.0
# Units Sold        0.0
# Unit Price        0.0
# Unit Cost         0.0
# Total Revenue     0.0
# Total Cost        0.0
# Total Profit      0.0
# dtype: float64

# %%
sales.duplicated().sum()
# Out:
# 0

# %%
sales['Order ID'].duplicated().sum()
# Out:
# 0

# %%
sales[['Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']].describe().round(2).T
# Out:
#                  count        mean         std     min        25%        50%  \
# Units Sold     10000.0     5002.86     2873.25    2.00    2530.75    4962.00
# Unit Price     10000.0      268.14      217.94    9.33     109.28     205.70
# Unit Cost      10000.0      188.81      176.45    6.92      56.67     117.11
# Total Revenue  10000.0  1333355.13  1465026.17  167.94  288551.08  800051.21
# Total Cost     10000.0   938265.78  1145914.07  124.56  164785.53  481605.84
# Total Profit   10000.0   395089.35   377554.96   43.38   98329.14  289099.02
#
#                       75%         max
# Units Sold        7472.00    10000.00
# Unit Price         437.20      668.27
# Unit Cost          364.69      524.96
# Total Revenue  1819143.39  6680026.92
# Total Cost     1183821.52  5241725.60
# Total Profit    566422.71  1738178.39

# %% [markdown]
# ---

# %% [markdown]
# ### Convert to Datetime

# %%
sales['Order Date'] = pd.to_datetime(sales['Order Date'])
sales['Ship Date'] = pd.to_datetime(sales['Ship Date'])
sales.reset_index()
# Out:
#       index                        Region                           Country  \
# 0         0            Sub-Saharan Africa                              Chad
# 1         1                        Europe                            Latvia
# 2         2  Middle East and North Africa                          Pakistan
# 3         3            Sub-Saharan Africa  Democratic Republic of the Congo
# 4         4                        Europe                    Czech Republic
# ...     ...                           ...                               ...
# 9995   9995                          Asia                              Laos
# 9996   9996                        Europe                     Liechtenstein
# 9997   9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998   9998            Sub-Saharan Africa                      South Africa
# 9999   9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0     Office Supplies        Online              L 2011-01-27  292494523
# 1           Beverages        Online              C 2015-12-28  361825549
# 2          Vegetables       Offline              C 2011-01-13  141515767
# 3           Household        Online              C 2012-09-11  500364005
# 4           Beverages        Online              C 2015-10-27  127481591
# ...               ...           ...            ...        ...        ...
# 9995        Beverages        Online              H 2014-07-15  199342048
# 9996        Cosmetics        Online              C 2012-10-27  763044106
# 9997       Vegetables       Offline              M 2013-02-14  848579967
# 9998             Meat        Online              L 2017-02-19  298185956
# 9999           Snacks       Offline              M 2016-04-12  824410903
#
#       Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0    2011-02-12        4484      651.21     524.96     2920025.64  2353920.64
# 1    2016-01-23        1075       47.45      31.79       51008.75    34174.25
# 2    2011-02-01        6515      154.06      90.93     1003700.90   592408.95
# 3    2012-10-06        7683      668.27     502.54     5134318.41  3861014.82
# 4    2015-12-05        3491       47.45      31.79      165647.95   110978.89
# ...         ...         ...         ...        ...            ...         ...
# 9995 2014-07-31        8597       47.45      31.79      407927.65   273298.63
# 9996 2012-11-01         562      437.20     263.33      245706.40   147991.46
# 9997 2013-03-20        2524      154.06      90.93      388847.44   229507.32
# 9998 2017-02-22        8706      421.89     364.69     3672974.34  3174991.14
# 9999 2016-04-16         361      152.58      97.44       55081.38    35175.84
#
#       Total Profit
# 0        566105.00
# 1         16834.50
# 2        411291.95
# 3       1273303.59
# 4         54669.06
# ...            ...
# 9995     134629.02
# 9996      97714.94
# 9997     159340.12
# 9998     497983.20
# 9999      19905.54
#
# [10000 rows x 15 columns]

# %%
#data pre processing:
sales['order_day_of_the_month']= sales['Order Date'].dt.day
sales['order_week_day']= sales['Order Date'].dt.dayofweek
sales['order_month']= sales['Order Date'].dt.month
sales['order_year']= sales['Order Date'].dt.year
sales['order_year']= sales['Order Date'].dt.year
sales['shipment_days_delay']= (sales['Ship Date'] - sales['Order Date']).dt.days

maping = {1:'jan',2:'feb',3:'march',4:'april',5:'may',6:'june',7:'july',8:'aug',9:'sep',10:'oct',11:'nov',12:'dec'}
sales['order_month']= sales['order_month'].map(maping)

sales.head()
# Out:
#                          Region                           Country  \
# 0            Sub-Saharan Africa                              Chad
# 1                        Europe                            Latvia
# 2  Middle East and North Africa                          Pakistan
# 3            Sub-Saharan Africa  Democratic Republic of the Congo
# 4                        Europe                    Czech Republic
#
#          Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0  Office Supplies        Online              L 2011-01-27  292494523
# 1        Beverages        Online              C 2015-12-28  361825549
# 2       Vegetables       Offline              C 2011-01-13  141515767
# 3        Household        Online              C 2012-09-11  500364005
# 4        Beverages        Online              C 2015-10-27  127481591
#
#    Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0 2011-02-12        4484      651.21     524.96     2920025.64  2353920.64
# 1 2016-01-23        1075       47.45      31.79       51008.75    34174.25
# 2 2011-02-01        6515      154.06      90.93     1003700.90   592408.95
# 3 2012-10-06        7683      668.27     502.54     5134318.41  3861014.82
# 4 2015-12-05        3491       47.45      31.79      165647.95   110978.89
#
#    Total Profit  order_day_of_the_month  order_week_day order_month  \
# 0     566105.00                      27               3         jan
# 1      16834.50                      28               0         dec
# 2     411291.95                      13               3         jan
# 3    1273303.59                      11               1         sep
# 4      54669.06                      27               1         oct
#
#    order_year  shipment_days_delay
# 0        2011                   16
# 1        2015                   26
# 2        2011                   19
# 3        2012                   25
# 4        2015                   39

# %%
sales.tail()
# Out:
#                   Region                           Country   Item Type  \
# 9995                Asia                              Laos   Beverages
# 9996              Europe                     Liechtenstein   Cosmetics
# 9997  Sub-Saharan Africa  Democratic Republic of the Congo  Vegetables
# 9998  Sub-Saharan Africa                      South Africa        Meat
# 9999                Asia                          Mongolia      Snacks
#
#      Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# 9995        Online              H 2014-07-15  199342048 2014-07-31
# 9996        Online              C 2012-10-27  763044106 2012-11-01
# 9997       Offline              M 2013-02-14  848579967 2013-03-20
# 9998        Online              L 2017-02-19  298185956 2017-02-22
# 9999       Offline              M 2016-04-12  824410903 2016-04-16
#
#       Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 9995        8597       47.45      31.79      407927.65   273298.63
# 9996         562      437.20     263.33      245706.40   147991.46
# 9997        2524      154.06      90.93      388847.44   229507.32
# 9998        8706      421.89     364.69     3672974.34  3174991.14
# 9999         361      152.58      97.44       55081.38    35175.84
#
#       Total Profit  order_day_of_the_month  order_week_day order_month  \
# 9995     134629.02                      15               1        july
# 9996      97714.94                      27               5         oct
# 9997     159340.12                      14               3         feb
# 9998     497983.20                      19               6         feb
# 9999      19905.54                      12               1       april
#
#       order_year  shipment_days_delay
# 9995        2014                   16
# 9996        2012                    5
# 9997        2013                   34
# 9998        2017                    3
# 9999        2016                    4

# %%
duration = sales['Order Date'].max() - sales['Order Date'].min()
duration
# Out:
# Timedelta('2765 days 00:00:00')

# %% [markdown]
# ### Size handling

# %%
sales[sales.select_dtypes('object').columns] = sales.select_dtypes('object').astype('category')
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Region                  10000 non-null  category
#  1   Country                 10000 non-null  category
#  2   Item Type               10000 non-null  category
#  3   Sales Channel           10000 non-null  category
#  4   Order Priority          10000 non-null  category
#  5   Order Date              10000 non-null  datetime64[ns]
#  6   Order ID                10000 non-null  int64
#  7   Ship Date               10000 non-null  datetime64[ns]
#  8   Units Sold              10000 non-null  int64
#  9   Unit Price              10000 non-null  float64
#  10  Unit Cost               10000 non-null  float64
#  11  Total Revenue           10000 non-null  float64
#  12  Total Cost              10000 non-null  float64
#  13  Total Profit            10000 non-null  float64
#  14  order_day_of_the_month  10000 non-null  int32
#  15  order_week_day          10000 non-null  int32
#  16  order_month             10000 non-null  category
#  17  order_year              10000 non-null  int32
#  18  shipment_days_delay     10000 non-null  int64
# dtypes: category(6), datetime64[ns](2), float64(5), int32(3), int64(3)
# memory usage: 973.9 KB

# %% [markdown]
# ---

# %%
sales.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit',
#        'order_day_of_the_month', 'order_week_day', 'order_month', 'order_year',
#        'shipment_days_delay'],
#       dtype='object')

# %%
sales['Region'].value_counts()
sales['Country'].value_counts()
# Out:
# Country
# Lithuania         72
# United Kingdom    72
# Moldova           71
# Seychelles        70
# Croatia           70
#                   ..
# Slovakia          42
# Greenland         41
# Tajikistan        40
# Saint Lucia       39
# Mali              35
# Name: count, Length: 185, dtype: int64

# %%
sales[['Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']].describe().round(2).T
# Out:
#                  count        mean         std     min        25%        50%  \
# Units Sold     10000.0     5002.86     2873.25    2.00    2530.75    4962.00
# Unit Price     10000.0      268.14      217.94    9.33     109.28     205.70
# Unit Cost      10000.0      188.81      176.45    6.92      56.67     117.11
# Total Revenue  10000.0  1333355.13  1465026.17  167.94  288551.08  800051.21
# Total Cost     10000.0   938265.78  1145914.07  124.56  164785.53  481605.84
# Total Profit   10000.0   395089.35   377554.96   43.38   98329.14  289099.02
#
#                       75%         max
# Units Sold        7472.00    10000.00
# Unit Price         437.20      668.27
# Unit Cost          364.69      524.96
# Total Revenue  1819143.39  6680026.92
# Total Cost     1183821.52  5241725.60
# Total Profit    566422.71  1738178.39

# %% [markdown]
# ---

# %% [markdown]
# # Exploratory Data Analysis - EDA 📊  &  Data Visualization 📈

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Top Selling Products 🎯 and Top Profitable Products 💰

# %% [markdown]
# ### 🎯 Analysis Objectives:
#
# * What are the best-selling products?
# * What are the highest-profit products?
# * Are there products that excel in certain country?
# * Are there products with low sales but high profits?
# * Are the highest-profitable products sold through a specific channel?

# %%
top_selling = sales.groupby('Item Type')['Units Sold'].sum().sort_values(ascending=False).reset_index()
top_selling.applymap(safe_comma_format)
# Out:
#           Item Type    Units Sold
# 0     Personal Care  4,402,827.00
# 1           Clothes  4,352,350.00
# 2         Household  4,336,803.00
# 3        Vegetables  4,238,098.00
# 4            Cereal  4,203,394.00
# 5         Baby Food  4,197,006.00
# 6            Snacks  4,122,781.00
# 7   Office Supplies  4,120,263.00
# 8         Cosmetics  4,103,290.00
# 9            Fruits  4,055,921.00
# 10             Meat  3,985,390.00
# 11        Beverages  3,910,436.00

# %%
top_product_profit = sales.groupby('Item Type')['Total Profit'].sum().sort_values(ascending=False).reset_index()
top_product_profit.applymap(safe_comma_format)
# Out:
#           Item Type    Total Profit
# 0         Household  718,738,361.19
# 1         Cosmetics  713,439,032.30
# 2   Office Supplies  520,183,203.75
# 3         Baby Food  402,324,995.16
# 4            Cereal  372,378,674.46
# 5           Clothes  319,636,584.00
# 6        Vegetables  267,551,126.74
# 7              Meat  227,964,308.00
# 8            Snacks  227,330,144.34
# 9     Personal Care  110,334,844.62
# 10        Beverages   61,237,427.76
# 11           Fruits    9,774,769.61

# %% [markdown]
# ## Data Visualization📊

# %%
# Create sub-plot
fig = make_subplots(rows=1, cols=2, subplot_titles=('Top Selling Products 🎯', 'Top Profitable Products 💰'))

# Add the first line chart (units sold)
fig.add_trace(
    go.Line(x=top_selling["Item Type"], y=top_selling["Units Sold"], name="Units Sold", marker_color='green'),
    row=1, col=1
)

# Add the second line chart (Total Profit)
fig.add_trace(
    go.Line(x=top_product_profit["Item Type"], y=top_product_profit["Total Profit"], name="Total Profit", marker_color='orange'), # تغيير اللون للتمييز
    row=1, col=2
)


fig.update_layout(
    height=500,      # Adjust the height.
    width=1200,      # Adjust the witdth
    showlegend=True  # To show Units Sold and Total Profit labels
)

# Rotate the x-axis labels for both subcharts.
fig.update_xaxes(tickangle=-90, row=1, col=1)
fig.update_xaxes(tickangle=-90, row=1, col=2)

fig.show(renderer='iframe')
# Out:
# /usr/local/lib/python3.11/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <iframe
#     scrolling="no"
#     width="1220px"
#     height="520"
#     src="iframe_figures/figure_22.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Insights 📌
# * The top-selling products were Personal Care and Clothes.
#
# * However, the products with the highest profitability were Household and Cosmetics.
#
# * Selling large quantities doesn't always translate to high profits; the profit margin makes a significant difference.

# %% [markdown]
# ### Recommendation 💡
# Focus on high-profit-margin products and re-evaluate the pricing and marketing strategies for products with good sales but low profitability.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Top Profitable Regions 🌍

# %% [markdown]
# ### 🎯 Analysis Objectives:
#
# * What are the most profitable areas?
# * What is the evolution of each region's performance over time?

# %%
top_region_profit = sales.groupby('Region')['Total Profit'].sum().sort_values(ascending=False).reset_index()
top_region_profit.applymap(safe_comma_format)
# Out:
#                               Region      Total Profit
# 0                             Europe  1,026,999,612.80
# 1                 Sub-Saharan Africa    999,642,091.50
# 2                               Asia    587,403,296.85
# 3       Middle East and North Africa    509,923,894.53
# 4  Central America and the Caribbean    403,357,849.72
# 5              Australia and Oceania    324,071,211.41
# 6                      North America     99,495,515.12

# %% [markdown]
# ## Data Visualization📊

# %%
fig = px.bar(
    top_region_profit,
    x='Region',
    y='Total Profit',
    title='Total Profit by Region',
    color='Total Profit',
    color_continuous_scale='tempo',
    width = 1000,
    height = 600
)
fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="1020px"
#     height="620"
#     src="iframe_figures/figure_24.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
years_region_profit = sales.groupby(['order_year', 'Region'])['Total Profit'].sum().reset_index()
years_region_profit
years_region_profit_sorted = years_region_profit.sort_values(by=['Total Profit'], ascending=[False])
years_region_profit_sorted.applymap(safe_comma_format)
# Out:
#    order_year                             Region    Total Profit
# 34       2014                 Sub-Saharan Africa  148,880,000.61
# 24       2013                             Europe  146,762,267.11
# 38       2015                             Europe  141,507,971.76
# 17       2012                             Europe  140,086,335.60
# 10       2011                             Europe  139,016,810.01
# 45       2016                             Europe  135,834,134.92
# 41       2015                 Sub-Saharan Africa  135,099,855.47
# 13       2011                 Sub-Saharan Africa  134,348,435.91
# 6        2010                 Sub-Saharan Africa  134,138,959.12
# 48       2016                 Sub-Saharan Africa  126,997,851.03
# 27       2013                 Sub-Saharan Africa  126,943,833.11
# 31       2014                             Europe  123,326,028.68
# 20       2012                 Sub-Saharan Africa  119,402,995.11
# 3        2010                             Europe  115,176,189.77
# 7        2011                               Asia   88,752,048.40
# 52       2017                             Europe   85,289,874.95
# 21       2013                               Asia   81,498,426.28
# 28       2014                               Asia   81,229,546.01
# 0        2010                               Asia   79,169,881.19
# 35       2015                               Asia   76,188,487.20
# 39       2015       Middle East and North Africa   74,333,067.49
# 55       2017                 Sub-Saharan Africa   73,830,161.14
# 42       2016                               Asia   72,445,787.26
# 25       2013       Middle East and North Africa   72,017,038.26
# 14       2012                               Asia   70,468,809.42
# 32       2014       Middle East and North Africa   70,242,225.88
# 46       2016       Middle East and North Africa   67,908,608.26
# 18       2012       Middle East and North Africa   67,500,881.69
# 37       2015  Central America and the Caribbean   65,840,093.13
# 4        2010       Middle East and North Africa   62,859,319.21
# 11       2011       Middle East and North Africa   62,854,290.20
# 23       2013  Central America and the Caribbean   57,542,522.60
# 16       2012  Central America and the Caribbean   54,060,946.29
# 30       2014  Central America and the Caribbean   52,152,854.43
# 44       2016  Central America and the Caribbean   51,071,936.79
# 36       2015              Australia and Oceania   49,265,096.21
# 9        2011  Central America and the Caribbean   49,104,872.97
# 22       2013              Australia and Oceania   49,037,544.50
# 29       2014              Australia and Oceania   46,829,881.25
# 2        2010  Central America and the Caribbean   46,332,187.46
# 43       2016              Australia and Oceania   43,819,800.90
# 8        2011              Australia and Oceania   42,090,453.08
# 49       2017                               Asia   37,650,311.09
# 15       2012              Australia and Oceania   35,124,245.61
# 1        2010              Australia and Oceania   34,072,924.03
# 53       2017       Middle East and North Africa   32,208,463.54
# 51       2017  Central America and the Caribbean   27,252,436.05
# 50       2017              Australia and Oceania   23,831,265.83
# 33       2014                      North America   19,687,748.79
# 19       2012                      North America   19,117,879.76
# 12       2011                      North America   12,710,491.04
# 5        2010                      North America   10,750,279.46
# 40       2015                      North America   10,601,986.65
# 47       2016                      North America    9,796,660.08
# 54       2017                      North America    8,712,113.29
# 26       2013                      North America    8,118,356.05

# %%
fig = px.area(
    years_region_profit_sorted,
    x='order_year',
    y='Total Profit',
    color='Region',
    title='Cumulative and Contributing Profit in Each Region',
    line_group='Region',
    labels={'Total Profit': 'Profit ($)', 'Year': 'Date'},
)

fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Total Profit',
    hovermode='x unified',
    template='plotly_white'
)

fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_26.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Insights 📌
# **Overall Profitability Trend**
# * Profitability showed continuous **growth** until 2015, followed by a **sharp decline** in 2016 and 2017.
#
# **Regional Contributions**
# * **Top-Contributing** Regions **Europe** and **Sub-Saharan Africa** are the primary pillars of profitability.
# * **Lowest-Contributing** Regions **North America** and **Australia and Oceania** have the lowest contribution to profits.
#
# **Recommendation**
# * Investigate the causes of the recent **decline in overall profits**. Develop action plans for the underperforming regions while leveraging the strengths in Europe and Sub-Saharan Africa.

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Online vs Offline 🛒

# %%
years_channel_profit = sales.groupby(['order_year', 'Sales Channel'])[['Total Profit', 'Units Sold']].sum().reset_index()
years_channel_profit.applymap(safe_comma_format)
# Out:
#    order_year Sales Channel    Total Profit    Units Sold
# 0        2010       Offline  232,770,342.76  2,879,012.00
# 1        2010        Online  249,729,397.48  3,166,065.00
# 2        2011       Offline  271,246,504.84  3,380,155.00
# 3        2011        Online  257,630,896.77  3,401,496.00
# 4        2012       Offline  261,813,407.89  3,357,659.00
# 5        2012        Online  243,948,685.59  3,252,090.00
# 6        2013       Offline  283,937,236.81  3,420,216.00
# 7        2013        Online  257,982,751.10  3,297,954.00
# 8        2014       Offline  280,464,372.27  3,504,716.00
# 9        2014        Online  261,883,913.38  3,266,398.00
# 10       2015       Offline  249,305,474.05  3,062,879.00
# 11       2015        Online  303,531,083.86  3,748,327.00
# 12       2016       Offline  262,343,606.82  3,356,735.00
# 13       2016        Online  245,531,172.42  3,199,318.00
# 14       2017       Offline  139,021,223.35  1,834,933.00
# 15       2017        Online  149,753,402.54  1,900,606.00

# %% [markdown]
# ### 🎯 Analysis Objectives:
# * Which sales channel makes more profits?
# * Is offline stronger in certain country?
# * Profitability Increasing Over Time in a Specific Channel?

# %% [markdown]
# ## Data Visualization📊

# %%
pie_channel = sales.groupby('Sales Channel')[['Total Profit', 'Units Sold']].sum().reset_index()
pie_channel.applymap(safe_comma_format)
# Out:
#   Sales Channel      Total Profit     Units Sold
# 0       Offline  1,980,902,168.79  24,796,305.00
# 1        Online  1,969,991,303.14  25,232,254.00

# %%
fig = px.pie(

    pie_channel,
    names = 'Sales Channel',
    values = 'Total Profit',
    title = 'Total Profit by Year and Sales Channel',

    hover_data=['Total Profit'],

)
fig.update_layout(
    width=600,   # Adjust the height
    height=600   # Adjust the witdth
)

# fig.update_traces(hole=0.4)

fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="620"
#     src="iframe_figures/figure_29.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.scatter(

    years_channel_profit,
    x = 'order_year',
    y = 'Total Profit',
    color = 'Sales Channel',
    size = 'Units Sold',
    hover_name = 'Sales Channel',
    title = 'Total Profit by Year and Sales Channel',
    labels = {'Total Profit' : 'Profit ($)', 'order_year' : 'Year'},
)


fig.update_layout(

    xaxis_title = 'Year',
    yaxis_title = 'Total Profit',
    width = 800,
    height = 600,
    template = 'plotly_white'
)

fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_30.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#product vs sales chaneels:
sales_chnl=pd.pivot_table(data=sales,index='Item Type',columns='Sales Channel',values='Units Sold',aggfunc='sum')

sales_on=sales_chnl[sales_chnl['Online']>sales_chnl['Offline']]

sales_on.plot(kind='bar',figsize=(10,5),title='products that sold more in online')
# Out:
# <Axes: title={'center': 'products that sold more in online'}, xlabel='Item Type'>

# %%
# product vs sales chaneels:
sales_chnl=pd.pivot_table(data=sales,index='Item Type',columns='Sales Channel',values='Units Sold',aggfunc='sum')

sales_on=sales_chnl[sales_chnl['Online']<sales_chnl['Offline']]

sales_on.plot(kind='bar',figsize=(10,5),title='products that sold more in offline')
# Out:
# <Axes: title={'center': 'products that sold more in offline'}, xlabel='Item Type'>

# %% [markdown]
# ### Insights 📌
# **Channel Contribution Balance**
# * Both sales channels, **Offline** and **Online**, contribute very similar proportions (approximately 50% each) to overall profits.
# * The channels are relatively balanced, and marketing efforts can be distributed evenly.
#
# **Annual Profitability Trends**
# * Profits have experienced fluctuations, with Online reaching its peak in 2015.
# * A sharp and notable decline in profits for both channels occurred in 2017, which warrants investigation.
# * ***Online*** demand is more consistent and widespread over time. Although total profit is lower, the number of orders and profit remain stable yearly, indicating that it is an important channel for maintaining a steady flow of sales.
# * ***Offline*** profits experience significant seasonal increases. This may be linked to sales seasons or specific campaigns, suggesting the potential for leveraging events and offers to improve online results as well.
#
# **Product Preferences by Channel**
# * **Offline** Channel excels in: Clothes, Cosmetics, Household, Snacks, and Vegetables.
# * **Online** Channel excels in: Baby Food, Beverages, Cereal, Fruits, Meat, Office Supplies, and Personal Care.

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Order Priority 🚦

# %% [markdown]
# ### 🎯 Analysis Objectives:
# * Which priority earns the most?
#
# * Do critical orders actually generate the highest profits?
#
# * What is the profit trend by priority over time?

# %% [markdown]
# ## Data Visualization📊

# %%
priority_profit = sales.groupby("Order Priority")["Total Profit"].sum().sort_values(ascending=False).reset_index()



fig = px.pie(

    priority_profit,
    names = 'Order Priority',
    values = 'Total Profit',
    title = 'Total Profit by Order Priority',

    hover_data=['Total Profit'],

)
fig.update_layout(
    width=600,   # Adjust the width
    height=600   # Adjust the height
)

fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="620"
#     src="iframe_figures/figure_33.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
yearly_priority_profit = sales.groupby(["order_year", "Order Priority"])["Total Profit"].sum().reset_index()

fig = px.line(
    yearly_priority_profit,
    x="order_year",
    y="Total Profit",
    color="Order Priority",
    title="Yearly Profit Trend by Order Priority",
    markers=True,
    # labels='Units Sold'
)
fig.update_layout(xaxis_title="Years", yaxis_title="Total Profit")
fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_34.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Insights 📌
# **Balanced Profit Distribution**
# * All order priority levels (C, H, L, M) contribute very similar proportions to the total profit. This indicates no significant reliance on any single priority level.
# * High/Critical orders don't always equal higher profits.
#
# **Parallel Trends Over Time**
# * Profits remained relatively stable and consistent across all priority levels from 2010 to 2016.

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Correlation Heatmap

# %% [markdown]
# ### 🎯 Analysis Objectives:
# * Does increasing units sold lead to increased profit?
# * Is there a relationship between unit price and cost?

# %%
col = ['Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit',]
sales_corr = sales[col].corr().round(3)
sales_corr
# Out:
#                Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# Units Sold          1.000      -0.013     -0.012          0.519       0.466
# Unit Price         -0.013       1.000      0.986          0.733       0.749
# Unit Cost          -0.012       0.986      1.000          0.723       0.760
# Total Revenue       0.519       0.733      0.723          1.000       0.988
# Total Cost          0.466       0.749      0.760          0.988       1.000
# Total Profit        0.597       0.571      0.500          0.882       0.798
#
#                Total Profit
# Units Sold            0.597
# Unit Price            0.571
# Unit Cost             0.500
# Total Revenue         0.882
# Total Cost            0.798
# Total Profit          1.000

# %% [markdown]
# ## Data Visualization📊

# %%
plt.figure(figsize=(10, 6))
# colormap = sns.color_palette("Greens")

sns.heatmap(sales_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix Between Numerical Variables")
plt.show()

# %% [markdown]
# ### Insights 🔍
# * The data is logical and valid, and there are no strange relationships that need further study.
#
# |The relationship between the two variables |       explanation                                            |
# | -------------------------------- | ------------------------------------------------------------- |
# | `Units Sold` & `Total Revenue`   | Strong positive correlation (the more sales, the more revenue)             |
# | `Units Sold` & `Total Profit`    | Positive correlation, but not always strong (a lot of selling does not always mean profit)|
# | `Unit Cost` & `Unit Price`       | Strong positive correlation (selling price increases with cost)          |
# | `Total Revenue` & `Total Profit` | Very strong relationship, but profit is affected by cost                   |

# %%
plt.figure(figsize=(13, 7))
plt.subplot(1, 3, 1)
sns.boxplot(y = sales['Units Sold'], color='lightgreen')
plt.title('Units Sold')

plt.subplot(1, 3, 2)
sns.boxplot(y = sales['Unit Price'], color='skyblue')
plt.title('Unit Price')

plt.subplot(1, 3, 3)
sns.boxplot(y = sales['Unit Cost'], color='salmon')
plt.title('Unit Cost')

plt.show()

# %%
plt.figure(figsize=(13, 7))
plt.subplot(1, 3, 1)
sns.boxplot(y = sales['Total Revenue'], color='lightgreen')
plt.title('Total Revenue')

plt.subplot(1, 3, 2)
sns.boxplot(y = sales['Total Cost'], color='skyblue')
plt.title('Total Cost')

plt.subplot(1, 3, 3)
sns.boxplot(y = sales['Total Profit'], color='salmon')
plt.title('Total Profit')

plt.show()

# %% [markdown]
# ## 6. Dominant Countries 🗺️

# %% [markdown]
# ### 🎯 Analysis Objectives:
# * Which countries generate the most sales and profits?
#
# * Are there countries that sell a lot but make little profit? Or vice versa?
#
# * Are there countries that rely on a specific type of product?

# %% [markdown]
# ## Data Visualization📊

# %%
country_profit = sales.groupby('Country')['Total Profit'].sum().sort_values(ascending=False).reset_index()

fig = px.bar(

    country_profit.head(10),
    x = 'Country',
    y = 'Total Profit',
    title = 'Top 10 Countries by Total Profit',
    color = 'Total Profit',
    color_continuous_scale = 'viridis',
    width = 1000,
    height = 600
)

fig.update_layout(xaxis_tickangle=-45)
fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="1020px"
#     height="620"
#     src="iframe_figures/figure_39.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
country_sales = sales.groupby('Country')['Units Sold'].sum().sort_values(ascending=False).reset_index()

fig = px.bar(

    country_sales.head(10),
    x = 'Country',
    y = 'Units Sold',
    title = 'Top 10 Countries by Units Sold',
    color = 'Units Sold',
    color_continuous_scale = 'viridis',
    width = 1000,
    height = 600
)

fig.update_layout(xaxis_tickangle=-45)
fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="1020px"
#     height="620"
#     src="iframe_figures/figure_40.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.scatter(
    sales,
    x='Units Sold',
    y='Total Profit',
    color='Item Type',  # color the dots according to the type of product.
    title='Units Sold vs Total Profit by Item Type',
    hover_data=['Country', 'Sales Channel', 'Order Priority'],
    opacity=0.7
)

fig.update_layout(
    xaxis_title='Units Sold',
    yaxis_title='Total Profit',
    template='plotly_white'
)

fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_41.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Insights 🔍
# * Clear Direct Relationship: Generally, as the number of units sold increases, so does the profit. However, this isn't always at the same rate.
#
# * High Volume, Low Profit: Some products sell in massive quantities but yield low profit. This could indicate either low-priced products or high-cost products.
#
# * Low Volume, High Profit: Certain products generate high profit from a small number of units, suggesting they are high-profit-margin products.

# %%
yearly_country_profit = sales.groupby(['order_year', 'Country'])['Total Profit'].sum().reset_index()

fig = px.area(
    yearly_country_profit[yearly_country_profit['Country'].isin(
        country_profit.head(5)['Country'])],  # Show top 5 country
    x='order_year',
    y='Total Profit',
    color='Country',
    title='Yearly Profit Trend of Top 5 Countries'
)
fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_42.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Insights 🔍
# * Some countries might have high sales but low profit, which indicates either low-priced or high-cost products.
# * Other countries might achieve high profits despite moderate sales, which indicates the sale of high-profitability products.
# * Yearly stability in some countries indicates stable demand.

# %% [markdown]
# ---

# %% [markdown]
# ## 7. Impact on shipping delays ⌛

# %% [markdown]
# ### 🎯 Analysis Objectives:
# * Does delay affect customer satisfaction or repeat purchases?
#
# * Are products that ship late less profitable?
#
# * Are there certain countries or channels where delays occur more than others?

# %%
delay = sales['shipment_days_delay'].max()
delay
# Out:
# 50

# %%
 sales['shipment_days_delay'].describe()
# Out:
# count    10000.00000
# mean        25.06020
# std         14.64797
# min          0.00000
# 25%         12.00000
# 50%         25.00000
# 75%         37.00000
# max         50.00000
# Name: shipment_days_delay, dtype: float64

# %%
fig = px.histogram(sales['shipment_days_delay'], x='shipment_days_delay',title='Distribution of Shipping Delay', nbins=100)

fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_45.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Insights 🔍
# * This graph shows a distribution. The distribution appears to be fairly even (almost "**flat**" or "**uniform**") across the entire range, with some peaks and valleys.
# * This chart gives you an instant overview of your shipping performance. We can clearly see that most shipments are delayed between 0 and 50 days.
# * We can notice that there are some peaks (high bars) that could indicate that there are certain weaknesses in the supply chain that are causing shipments to back up and be delayed at these points in time.

# %%
fig = px.scatter(
    sales,
    x='shipment_days_delay',
    y='Total Profit',
    # color='Item Type',  # color the dots according to the type of product.
    title='Shipping Delay vs Profit',
    opacity=0.7
)

fig.update_layout(
    xaxis_title='shipment_days_delay',
    yaxis_title='Total Profit',
    template='plotly_white'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f230d5e7-088d-4e45-85aa-c582cf1033f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f230d5e7-088d-4e45-85aa-c582cf1033f7")) {                    Plotly.newPlot(                        "f230d5e7-088d-4e45-85aa-c582cf1033f7",                        [{"hovertemplate":"shipment_days_delay=%{x}\u003cbr\u003eTotal Profit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[16,26,19,25,39,42,28,32,50,16,29,26,5,6,30,15,15,21,37,6,35,17,9,9,24,2,4,30,40,36,31,27,40,24,45,8,33,25,5,31,25,47,19,4,26,48,46,35,42,35,42,30,32,16,15,50,3,50,23,49,13,43,25,38,21,3,28,23,33,40,39,12,8,10,16,14,3,21,19,37,27,31,2,36,36,48,27,21,40,28,50,0,45,32,27,31,9,15,17,20,41,38,30,26,48,4,21,6,38,26,49,20,18,8,21,24,48,10,47,26,33,40,32,34,32,3,35,5,3,9,14,49,5,16,28,21,45,32,32,31,29,13,36,36,16,19,47,44,15,5,23,12,33,33,21,49,27,6,0,12,6,36,18,9,27,28,32,49,49,41,0,38,27,33,30,34,22,10,29,46,41,33,6,31,40,7,18,47,29,42,23,1,15,44,30,2,5,21,45,8,9,32,26,26,33,34,31,13,35,35,19,30,23,43,47,31,4,14,22,26,38,9,3,22,31,34,48,27,42,47,13,50,27,5,8,47,45,17,40,26,4,41,15,46,12,34,44,13,26,3,33,37,4,8,40,25,4,6,23,34,34,4,39,23,1,10,48,49,14,33,4,20,31,29,19,44,8,7,49,28,4,25,0,31,27,40,34,10,34,10,4,23,34,44,22,28,34,48,44,33,41,30,27,46,14,50,30,23,11,12,10,24,40,28,26,6,7,3,35,27,21,47,44,45,41,15,12,16,22,17,47,50,25,9,6,3,5,1,48,36,22,0,29,2,32,13,7,14,44,49,43,26,15,14,40,48,4,18,9,36,18,18,7,49,15,21,43,44,2,36,22,30,39,20,4,13,32,31,47,3,38,26,7,7,17,15,44,32,25,3,13,37,21,1,25,29,13,14,36,16,7,2,3,5,13,21,37,6,38,30,43,25,40,36,29,20,25,48,3,50,3,21,24,20,31,16,50,42,17,41,36,20,19,0,43,13,45,4,26,31,1,11,46,29,48,28,7,15,41,11,21,49,38,21,43,36,49,14,31,36,29,48,44,6,38,31,39,3,33,20,23,38,22,25,5,14,12,1,44,43,12,8,46,30,30,2,18,34,22,44,19,13,48,38,8,24,14,43,42,26,29,18,27,26,50,20,23,32,35,6,37,1,42,37,27,43,29,16,0,13,3,4,15,21,23,9,30,24,47,38,1,30,31,48,38,47,34,48,47,32,14,45,37,43,28,47,15,38,35,12,40,25,42,49,18,12,6,13,8,6,37,14,18,16,41,9,5,50,26,6,28,13,0,14,44,16,22,39,10,15,48,40,36,19,37,23,28,35,46,49,44,21,34,22,42,35,7,3,30,34,25,49,16,27,44,16,7,21,22,13,13,25,18,50,39,45,39,31,45,40,43,16,36,17,38,13,23,35,31,29,12,1,30,22,11,23,44,50,29,8,30,20,22,16,46,42,50,2,49,20,18,27,47,16,36,46,49,36,11,17,11,37,0,50,43,27,13,0,1,15,7,28,45,8,39,40,29,15,17,43,14,42,49,46,7,48,43,6,16,40,5,32,49,26,47,31,13,15,23,10,16,13,42,30,15,29,12,45,20,21,41,14,38,46,37,47,26,11,6,49,42,27,8,28,44,49,50,44,40,35,39,2,37,43,35,13,45,32,43,32,18,8,22,18,18,31,31,29,0,7,27,23,24,46,17,6,46,2,9,39,23,36,12,27,15,5,34,28,30,16,31,1,24,29,11,4,5,49,33,45,33,36,4,29,13,46,33,17,4,38,27,15,14,20,43,33,1,49,40,26,22,33,25,3,36,31,6,22,50,49,42,42,21,46,40,18,9,29,6,9,20,6,0,25,12,36,30,21,44,25,3,5,22,32,27,37,5,14,9,22,1,30,8,20,17,38,31,39,12,44,37,34,43,6,32,16,17,33,25,41,44,33,23,17,29,12,36,2,32,31,18,4,9,44,31,32,21,11,30,41,22,40,24,41,22,38,20,39,29,13,26,43,50,23,0,10,43,25,1,50,15,29,35,18,25,40,11,25,31,17,36,26,40,19,18,29,9,2,15,44,48,25,35,27,13,45,35,36,13,20,24,30,5,8,9,14,48,18,48,50,48,5,49,43,14,30,19,0,3,49,17,31,24,18,0,43,34,49,27,44,41,47,3,41,2,21,40,43,27,28,42,6,22,26,18,41,45,22,27,2,4,26,26,0,7,45,23,41,11,35,25,34,26,6,41,35,7,15,27,3,14,19,43,46,3,28,46,21,34,48,43,38,12,37,43,1,48,2,2,21,47,3,31,5,18,47,34,10,19,41,22,46,7,44,1,17,42,12,30,34,29,4,15,4,27,29,15,35,45,43,39,34,38,3,43,9,16,20,35,18,37,50,24,19,8,50,16,20,37,28,20,29,31,44,45,2,50,2,46,50,49,14,33,28,37,36,12,45,22,25,43,8,13,40,33,26,15,37,39,5,39,26,18,5,41,14,31,34,28,9,33,48,9,18,33,4,43,50,39,12,36,11,8,30,46,11,49,14,30,7,17, ...

# %% [markdown]
# ### Insights 🔍
# * The points are largely randomly spread.
#
# * There is no clear uptrend (the longer the delay, the higher the profit) or downtrend (the longer the delay, the lower the profit).
#
# * The most important note is that there is no clear pattern or direct relationship between shipping delays and total profits, or in other words, an increase in delays does not automatically mean a decrease in profits.

# %% [markdown]
# ## 8. Drop of 2017 📉

# %%
year_2017 = sales[sales['order_year'] == 2017]
year_2017
# Out:
#                                  Region                 Country  \
# 7                                  Asia                   China
# 25                               Europe           Liechtenstein
# 52                   Sub-Saharan Africa            South Africa
# 59                               Europe              Luxembourg
# 76                   Sub-Saharan Africa                 Senegal
# ...                                 ...                     ...
# 9945       Middle East and North Africa                 Bahrain
# 9949  Central America and the Caribbean  Saint Kitts and Nevis
# 9975                      North America                  Mexico
# 9985                               Asia                  Brunei
# 9998                 Sub-Saharan Africa            South Africa
#
#             Item Type Sales Channel Order Priority Order Date   Order ID  \
# 7           Baby Food        Online              C 2017-04-10  564251220
# 25         Vegetables       Offline              L 2017-02-26  223957431
# 52             Cereal        Online              M 2017-07-21  289660394
# 59      Personal Care        Online              L 2017-02-24  835580909
# 76             Fruits       Offline              H 2017-07-28  672654092
# ...               ...           ...            ...        ...        ...
# 9945        Beverages        Online              L 2017-04-02  387296664
# 9949       Vegetables       Offline              H 2017-01-28  683105266
# 9975           Cereal        Online              M 2017-07-04  783641326
# 9985  Office Supplies       Offline              L 2017-07-19  144625842
# 9998             Meat        Online              L 2017-02-19  298185956
#
#       Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 7    2017-05-12        3330      255.28     159.42      850082.40   530868.60
# 25   2017-02-28        2835      154.06      90.93      436760.10   257786.55
# 52   2017-08-22        5802      205.70     117.11     1193471.40   679472.22
# 59   2017-04-14        5814       81.73      56.67      475178.22   329479.38
# 76   2017-07-31        2148        9.33       6.92       20040.84    14864.16
# ...         ...         ...         ...        ...            ...         ...
# 9945 2017-05-15        8544       47.45      31.79      405412.80   271613.76
# 9949 2017-02-01        4883      154.06      90.93      752274.98   444011.19
# 9975 2017-08-18        5737      205.70     117.11     1180100.90   671860.07
# 9985 2017-07-24        6855      651.21     524.96     4464044.55  3598600.80
# 9998 2017-02-22        8706      421.89     364.69     3672974.34  3174991.14
#
#       Total Profit  order_day_of_the_month  order_week_day order_month  \
# 7        319213.80                      10               0       april
# 25       178973.55                      26               6         feb
# 52       513999.18                      21               4        july
# 59       145698.84                      24               4         feb
# 76         5176.68                      28               4        july
# ...            ...                     ...             ...         ...
# 9945     133799.04                       2               6       april
# 9949     308263.79                      28               5         jan
# 9975     508240.83                       4               1        july
# 9985     865443.75                      19               2        july
# 9998     497983.20                      19               6         feb
#
#       order_year  shipment_days_delay
# 7           2017                   32
# 25          2017                    2
# 52          2017                   32
# 59          2017                   49
# 76          2017                    3
# ...          ...                  ...
# 9945        2017                   43
# 9949        2017                    4
# 9975        2017                   45
# 9985        2017                    5
# 9998        2017                    3
#
# [777 rows x 19 columns]

# %%
formatted_year_2017 = year_2017.describe().round(2).T
formatted_year_2017.applymap(safe_comma_format)
# Out:
#                        count                           mean  \
# Order Date               777  2017-04-19 05:28:01.853281792
# Order ID                 777                 543,441,542.80
# Ship Date                777  2017-05-13 09:06:43.088803072
# Units Sold               777                       4,807.64
# Unit Price               777                         268.14
# Unit Cost                777                         189.55
# Total Revenue            777                   1,263,449.29
# Total Cost               777                     891,795.98
# Total Profit             777                     371,653.32
# order_day_of_the_month   777                          15.23
# order_week_day           777                           2.96
# order_year               777                           2017
# shipment_days_delay      777                          24.15
#
#                                         min                  25%  \
# Order Date              2017-01-01 00:00:00  2017-02-24 00:00:00
# Order ID                     100,621,736.00       316,217,267.00
# Ship Date               2017-01-02 00:00:00  2017-03-20 00:00:00
# Units Sold                               15                 2221
# Unit Price                             9.33               109.28
# Unit Cost                              6.92                56.67
# Total Revenue                        942.33           283,229.05
# Total Cost                           698.92           164,577.28
# Total Profit                         243.41            96,385.92
# order_day_of_the_month                    1                    8
# order_week_day                            0                    1
# order_year                             2017                 2017
# shipment_days_delay                       0                   11
#
#                                         50%                  75%  \
# Order Date              2017-04-20 00:00:00  2017-06-12 00:00:00
# Order ID                     537,244,594.00       763,408,029.00
# Ship Date               2017-05-14 00:00:00  2017-07-07 00:00:00
# Units Sold                         4,659.00             7,247.00
# Unit Price                           205.70               421.89
# Unit Cost                            117.11               263.33
# Total Revenue                    763,052.58         1,581,970.16
# Total Cost                       477,728.10         1,089,922.87
# Total Profit                     253,510.00           527,703.67
# order_day_of_the_month                   15                   23
# order_week_day                            3                    5
# order_year                             2017                 2017
# shipment_days_delay                      24                   37
#
#                                         max             std
# Order Date              2017-07-28 00:00:00             nan
# Order ID                     995,923,364.00  259,638,195.03
# Ship Date               2017-09-10 00:00:00             nan
# Units Sold                         9,992.00        2,883.30
# Unit Price                           668.27          211.68
# Unit Cost                            524.96          172.23
# Total Revenue                  6,658,642.28    1,407,123.75
# Total Cost                     5,241,725.60    1,101,867.22
# Total Profit                   1,732,614.55      361,656.20
# order_day_of_the_month                   31            8.73
# order_week_day                            6            1.96
# order_year                             2017               0
# shipment_days_delay                      50           14.82

# %% [markdown]
# ### Relative Change Analysis (YOY Change)
# * This shows you how many % drops there were in 2017.

# %%
# Relative Change Analysis (YOY Change)
# This shows you how many % drops there were in 2017.
year_revenue = sales.groupby('order_year')['Total Revenue'].sum()
revenue_diff = year_revenue.pct_change().round(2) * 100
print(revenue_diff)
# Out:
# order_year
# 2010     NaN
# 2011    16.0
# 2012    -7.0
# 2013     6.0
# 2014     3.0
# 2015     1.0
# 2016    -9.0
# 2017   -43.0
# Name: Total Revenue, dtype: float64

# %% [markdown]
# ### 🔍 Analysis of products that disappeared

# %%
products_2016 = set(sales[sales['order_year'] == 2016]['Item Type'].unique())
products_2017 = set(sales[sales['order_year'] == 2017]['Item Type'].unique())
missing = products_2016 - products_2017
print("Products that disappeared in 2017: ", missing)
# Out:
# Products that disappeared in 2017:  set()

# %% [markdown]
# 🔍👆🏻
# * No products disappeared in 2017 compared to 2016.
# * This means that all products that were sold in 2016 were available in 2017.
# * This means that the reason for the drop is not that a product disappeared completely.

# %%
plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
sales.groupby('order_year')['Units Sold'].sum().plot(kind='bar', title='Total Units Sold by Year')

plt.subplot(1, 3, 2)
sales.groupby('order_year')['Unit Price'].mean().plot(kind='line', marker='o', title='Average Unit Price by Year')

plt.subplot(1, 3, 3)
sales.groupby('order_year')['shipment_days_delay'].mean().plot(kind='line', marker='o', title='Avg Shipping Delay by Year')
# Out:
# <Axes: title={'center': 'Avg Shipping Delay by Year'}, xlabel='order_year'>

# %% [markdown]
# 🔍 Analysis of the Visualizations:
#
# 📊 1. Total Units Sold by Year
# * There is a very clear and significant drop in 2017 — from around 6.7 million units to less than 4 million.
# * 👉 This confirms that the drop is real and stems from a decrease in sales volume, not just profit.
#
# 📈 2. Average Unit Price by Year
# * The unit price in 2017 remained almost the same as in 2016 and did not drop.
# * 👉 This indicates that pricing is not the issue.
#
# 🚚 3. Average Shipping Delay by Year
# * Interestingly, shipping delays significantly decreased in 2017!
# * 👉 This is the opposite of what we'd expect — faster shipping should usually support higher sales, not a decline.

# %% [markdown]
# 🧠 Insight Summary:
#
# Although shipping became faster in 2017, the number of units sold dropped sharply, while prices remained nearly constant. This suggests that the decline in sales is not due to pricing or delivery issues, but may instead be linked to other factors such as market changes, reduced demand, or a cut in marketing budgets.

# %% [markdown]
# ---
